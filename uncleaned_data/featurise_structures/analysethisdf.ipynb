# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("HighthroughputDFTcalculationsofformationenergystabilityandoxygenvacancyformationenergyofABO3perovskites.csv")
df.head()
# Out:
#   Chemical formula   A   B  In literature          Valence A  \
# 0            Ac2O3  Ac  Ac          False  element not in BV
# 1           AcAgO3  Ac  Ag          False  element not in BV
# 2           AcAlO3  Ac  Al          False  element not in BV
# 3           AcAsO3  Ac  As          False  element not in BV
# 4           AcAuO3  Ac  Au          False  element not in BV
#
#            Valence B  Radius A [ang]  Radius B [ang] Lowest distortion  \
# 0  element not in BV            1.12            1.12             cubic
# 1  element not in BV            1.12            0.95      orthorhombic
# 2  element not in BV            1.12            0.54             cubic
# 3  element not in BV            1.12            0.52      orthorhombic
# 4  element not in BV            1.12            0.93      orthorhombic
#
#   Formation energy [eV/atom]  ... Magnetic moment [mu_B]  \
# 0                     -2.732  ...                  0.000
# ...

# %%
df["Lowest distortion"].value_counts()
# Out:
# Lowest distortion
# cubic           3253
# orthorhombic    1573
# rhombohedral     323
# tetragonal       127
# -                 53
# Name: count, dtype: int64

# %%
z = df[df["Lowest distortion"] == "rhombohedral"]
z
# Out:
#      Chemical formula   A   B  In literature          Valence A  \
# 12             AcCoO3  Ac  Co          False  element not in BV
# 32             AcMgO3  Ac  Mg          False  element not in BV
# 81             AgBiO3  Ag  Bi          False                  1
# 82             AgCaO3  Ag  Ca          False       not balanced
# 100            AgIrO3  Ag  Ir          False                  1
# ...               ...  ..  ..            ...                ...
# 5224           ZnPaO3  Zn  Pa          False  element not in BV
# 5225           ZnPbO3  Zn  Pb          False                  2
# 5232           ZnReO3  Zn  Re          False                  2
# 5241           ZnTaO3  Zn  Ta          False                  2
# 5251            ZnWO3  Zn   W          False                  2
#
#               Valence B  Radius A [ang]  Radius B [ang] Lowest distortion  \
# 12    element not in BV            1.12            0.63      rhombohedral
# ...

# %%
plt.figure(figsize=(22, 6))
plt.hist(z["alpha [deg]"], bins=20)
plt.xlabel('Beta (degrees)')
plt.ylabel('Frequency')

# Customize x-axis labels for better legibility
plt.xticks(rotation=90, ha='right')  # Rotate the labels at a 45-degree angle

plt.tight_layout()  # Adjust layout for better appearance
plt.show()
